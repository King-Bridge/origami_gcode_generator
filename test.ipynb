# %%
from data_loader import read_data_file, draw_polygons
from polygon_manipulator import add_hinges, find_outer_countour

# %%
# filename = 'data_files/single_90.dat'
# filename = 'data_files/single_180.dat'
# filename = 'data_files/zig-zag.dat'
filename = 'data_files/cube.dat'

polygons = read_data_file(filename)
draw_polygons(polygons)

# %%
polygons_final = add_hinges(polygons)
draw_polygons(polygons_final)

# %%
outer_countour = find_outer_countour(polygons)
draw_polygons([[outer_countour, []]])
